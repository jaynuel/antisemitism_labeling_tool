# %%
# Importing libraries
import sys
#!{sys.executable} -m pip install <library>
import pandas as pd
import numpy as np
from timeit import timeit
import boto3
import s3fs
import datetime as dt
import os
import tweepy
import json
from io import StringIO
import io

# %%
# Bucket Keys
aws_access_key_id= 'AKIA44IVHR33AYIJWJDH',
aws_secret_access_key='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'

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('annotationoutput')
# Iterates through all the objects, doing the pagination for you. Each obj
# is an ObjectSummary, so it doesn't contain the body. You'll need to call
# get to get the whole body.
list1 = []
for obj in bucket.objects.all():
    key = obj.key
    data = obj.get()['Body'].read()
    list1.append(pd.read_csv(io.BytesIO(data), header=0, delimiter=",", low_memory=False))

# %%
list1
# Out:
# [Empty DataFrame
#  Columns: [{"id": 1,  "created_username": " olivera@mail.yu.edu,  1",  "created_ago": "1\u00a0hour,  49\u00a0minutes",  "task": {"id": 1,  "data": {"image": "s3://tweetsdatatest/tweets_test120220219.csv"},  "meta": {},  "created_at": "2022-02-26T19:45:04.995912Z",  "updated_at": "2022-03-19T17:47:12.195781Z",  "is_labeled": false,  "overlap": 1,  "project": 1,  "file_upload": null},  "completed_by": {"id": 1,  "first_name": "",  "last_name": "",  "email": "olivera@mail.yu.edu"},  "result": [],  "was_cancelled": true,  "ground_truth": false,  "created_at": "2022-03-19T17:47:11.607751Z",  "updated_at": "2022-03-19T17:47:11.608751Z",  "lead_time": 5.381,  "parent_prediction": null,  "parent_annotation": null}]
#  Index: []
#
#  [0 rows x 26 columns],
#  Empty DataFrame
#  Columns: [{"id": 2,  "created_username": " olivera@mail.yu.edu,  1",  "created_ago": "1\u00a0hour,  49\u00a0minutes",  "task": {"id": 2,  "data": {"image": "s3://tweetsdatatest/tweets_test220220319.csv"},  "meta": {},  "created_at": "2022-03-19T16:51:24.557485Z",  "updated_at": "2022-03-19T17:47:15.738465Z",  "is_labeled": false,  "overlap": 1,  "project": 1,  "file_upload": null},  "completed_by": {"id": 1,  "first_name": "",  "last_name": "",  "email": "olivera@mail.yu.edu"},  "result": [],  "was_cancelled": true,  "ground_truth": false,  "created_at": "2022-03-19T17:47:15.458588Z",  "updated_at": "2022-03-19T17:47:15.458588Z",  "lead_time": 2.256,  "parent_prediction": null,  "parent_annotation": null}]
#  Index: []
#
#  [0 rows x 26 columns],
#  Empty DataFrame
#  Columns: [{"id": 3,  "created_username": " olivera@mail.yu.edu,  1",  "created_ago": "29\u00a0minutes",  "task": {"id": 3,  "data": {"image": "s3://tweetsdatatest/tweets_test320220319.csv"},  "meta": {},  "created_at": "2022-03-19T17:53:34.764420Z",  "updated_at": "2022-03-19T19:07:16.083763Z",  "is_labeled": false,  "overlap": 1,  "project": 1,  "file_upload": null},  "completed_by": {"id": 1,  "first_name": "",  "last_name": "",  "email": "olivera@mail.yu.edu"},  "result": [],  "was_cancelled": true,  "ground_truth": false,  "created_at": "2022-03-19T19:07:15.723555Z",  "updated_at": "2022-03-19T19:07:15.723555Z",  "lead_time": 2.773,  "parent_prediction": null,  "parent_annotation": null}]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [{"id": 4,  "created_username": " olivera@mail.yu.edu,  1",  "created_ago": "0\u00a0minutes",  "task": {"id": 12,  "data": {"image": "s3://picsbuckettest/pic_01.png"},  "meta": {},  "created_at": "2022-03-19T19:30:28.776070Z",  "updated_at": "2022-03-19T19:35:51.111550Z",  "is_labeled": true,  "overlap": 1,  "project": 1,  "file_upload": null},  "completed_by": {"id": 1,  "first_name": "",  "last_name": "",  "email": "olivera@mail.yu.edu"},  "result": [{"value": {"choices": ["Antisemitic"]},  "id": "sScu_pr3Kn",  "from_name": "choice",  "to_name": "image",  "type": "choices",  "origin": "manual"}],  "was_cancelled": false,  "ground_truth": false,  "created_at": "2022-03-19T19:35:50.763951Z",  "updated_at": "2022-03-19T19:35:50.763951Z",  "lead_time": 137.298,  "parent_prediction": null,  "parent_annotation": null}]
#  Index: []
#
#  [0 rows x 30 columns]]

# %%
df = pd.DataFrame.from_records(list1)
df
# Out:
#          0                                           1    2   \
# 0  {"id": 1   "created_username": " olivera@mail.yu.edu   1"
# 1  {"id": 2   "created_username": " olivera@mail.yu.edu   1"
# 2  {"id": 3   "created_username": " olivera@mail.yu.edu   1"
# 3  {"id": 4   "created_username": " olivera@mail.yu.edu   1"
#
#                                   3                   4   \
# 0        "created_ago": "1\u00a0hour    49\u00a0minutes"
# 1        "created_ago": "1\u00a0hour    49\u00a0minutes"
# 2   "created_ago": "29\u00a0minutes"    "task": {"id": 3
# 3    "created_ago": "0\u00a0minutes"   "task": {"id": 12
#
#                                                   5   \
# 0                                   "task": {"id": 1
# 1                                   "task": {"id": 2
# 2   "data": {"image": "s3://tweetsdatatest/tweets...
# 3   "data": {"image": "s3://picsbuckettest/pic_01...
#
#                                                   6   \
# 0   "data": {"image": "s3://tweetsdatatest/tweets...
# 1   "data": {"image": "s3://tweetsdatatest/tweets...
# 2                                         "meta": {}
# 3                                         "meta": {}
#
#                                              7   \
# 0                                    "meta": {}
# 1                                    "meta": {}
# 2   "created_at": "2022-03-19T17:53:34.764420Z"
# 3   "created_at": "2022-03-19T19:30:28.776070Z"
#
#                                              8   \
# 0   "created_at": "2022-02-26T19:45:04.995912Z"
# 1   "created_at": "2022-03-19T16:51:24.557485Z"
# 2   "updated_at": "2022-03-19T19:07:16.083763Z"
# 3   "updated_at": "2022-03-19T19:35:51.111550Z"
#
#                                              9   ...  \
# 0   "updated_at": "2022-03-19T17:47:12.195781Z"  ...
# 1   "updated_at": "2022-03-19T17:47:15.738465Z"  ...
# 2                           "is_labeled": false  ...
# 3                            "is_labeled": true  ...
#
#                                              20  \
# 0                         "ground_truth": false
# 1                         "ground_truth": false
# 2   "created_at": "2022-03-19T19:07:15.723555Z"
# 3                            "to_name": "image"
#
#                                              21  \
# 0   "created_at": "2022-03-19T17:47:11.607751Z"
# 1   "created_at": "2022-03-19T17:47:15.458588Z"
# 2   "updated_at": "2022-03-19T19:07:15.723555Z"
# 3                             "type": "choices"
#
#                                              22                          23  \
# 0   "updated_at": "2022-03-19T17:47:11.608751Z"          "lead_time": 5.381
# 1   "updated_at": "2022-03-19T17:47:15.458588Z"          "lead_time": 2.256
# 2                            "lead_time": 2.773   "parent_prediction": null
# 3                          "origin": "manual"}]      "was_cancelled": false
#
#                             24                                            25  \
# 0    "parent_prediction": null                    "parent_annotation": null}
# 1    "parent_prediction": null                    "parent_annotation": null}
# 2   "parent_annotation": null}                                          None
# 3        "ground_truth": false   "created_at": "2022-03-19T19:35:50.763951Z"
#
#                                              26                     27  \
# 0                                          None                   None
# 1                                          None                   None
# 2                                          None                   None
# 3   "updated_at": "2022-03-19T19:35:50.763951Z"   "lead_time": 137.298
#
#                            28                           29
# 0                        None                         None
# 1                        None                         None
# 2                        None                         None
# 3   "parent_prediction": null   "parent_annotation": null}
#
# [4 rows x 30 columns]
